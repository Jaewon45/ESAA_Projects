# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Jaewon/ESAA/data_from2022.csv")

# %%
#성별 별 MESURE_IEM_001_VALUE boxplot
box1=plt.subplots()
box1=sns.boxplot(x='SEXDSTN_FLAG_CD', y='MESURE_IEM_001_VALUE', data=data)

#성별 별 MESURE_IEM_002_VALUE boxplot
box2=plt.subplots()
box2=sns.boxplot(x='SEXDSTN_FLAG_CD', y='MESURE_IEM_002_VALUE', data=data)

#성별 별 MESURE_IEM_003_VALUE boxplot
box3=plt.subplots()
box3=sns.boxplot(x='SEXDSTN_FLAG_CD', y='MESURE_IEM_003_VALUE', data=data)

#성별 별 MESURE_IEM_005_VALUE boxplot
box5=plt.subplots()
box5=sns.boxplot(x='SEXDSTN_FLAG_CD', y='MESURE_IEM_005_VALUE', data=data)

#성별 별 MESURE_IEM_006_VALUE boxplot
box6=plt.subplots()
box6=sns.boxplot(x='SEXDSTN_FLAG_CD', y='MESURE_IEM_006_VALUE', data=data)

#성별 별 MESURE_IEM_012_VALUE boxplot
box12=plt.subplots()
box12=sns.boxplot(x='SEXDSTN_FLAG_CD', y='MESURE_IEM_012_VALUE', data=data)

#성별 별 MESURE_IEM_018_VALUE boxplot
box18=plt.subplots()
box18=sns.boxplot(x='SEXDSTN_FLAG_CD', y='MESURE_IEM_018_VALUE', data=data)
